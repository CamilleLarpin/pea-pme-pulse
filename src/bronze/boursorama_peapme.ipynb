# %% [markdown]
# # boursorama_peapme
#
# 1. Lecture du listing Boursorama PEA-PME par lettre (A..Z + 0)
# 2. Extraction des infos marché depuis `data-ist-init`
# 3. Suivi du lien détail de chaque société
# 4. Extraction de l’ISIN dans la fiche valeur
# 5. Export CSV final prêt pour le mapping yfinance

# %%
# Imports
import csv
import html
import json
import re
import time
from typing import Any, Dict, Optional, List
from urllib.parse import urljoin

import requests
from bs4 import BeautifulSoup
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

# %%
# Configuration générale

BASE_URL = "https://www.boursorama.com/bourse/actions/cotations/"
MARKET = "PEAPME"
LETTERS = list("ABCDEFGHIJKLMNOPQRSTUVWXYZ") + ["0"]

# Délai recommandé entre requêtes pour rester poli vis-à-vis du site
DELAY_SECONDS = 0.3

# CSV de sortie
OUTPUT_CSV = "boursorama_peapme_final.csv"

# En-têtes HTTP : User-Agent obligatoire
HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/123.0.0.0 Safari/537.36"
    ),
    "Accept-Language": "fr-FR,fr;q=0.9,en;q=0.8",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8",
    "Connection": "keep-alive",
}

# %%
# Session HTTP avec retries

def make_session() -> requests.Session:
    """
    Crée une session requests réutilisable.
    On ajoute des retries sur les codes transitoires pour rendre le script
    plus robuste sur une grande série de requêtes.
    """
    session = requests.Session()
    session.headers.update(HEADERS)

    retry = Retry(
        total=5,
        connect=5,
        read=5,
        backoff_factor=0.5,
        status_forcelist=(429, 500, 502, 503, 504),
        allowed_methods=frozenset(["GET"]),
    )

    adapter = HTTPAdapter(max_retries=retry, pool_connections=10, pool_maxsize=10)
    session.mount("https://", adapter)
    session.mount("http://", adapter)
    return session


SESSION = make_session()


def fetch_html(url: str, params: Optional[dict] = None) -> str:
    """
    Fait un GET et renvoie le HTML brut.
    """
    response = SESSION.get(url, params=params, timeout=30)
    response.raise_for_status()
    return response.text

# %%
# Helpers de parsing JSON / recherche de valeurs imbriquées

def extract_json_like(text: str) -> Any:
    """
    Tente de parser une chaîne potentiellement JSON encodée / échappée.
    Certaines valeurs HTML peuvent contenir des entités ou du JSON inline.
    """
    if not text:
        return {}

    # Décodage des entités HTML éventuelles
    text = html.unescape(text).strip()

    # 1) Essai direct
    try:
        return json.loads(text)
    except json.JSONDecodeError:
        pass

    # 2) Si du texte parasite entoure le JSON, on récupère le premier bloc {...}
    match = re.search(r"\{.*\}", text, flags=re.DOTALL)
    if match:
        try:
            return json.loads(match.group(0))
        except json.JSONDecodeError:
            return {}

    return {}


def find_first_value(obj: Any, keys: List[str]) -> Optional[Any]:
    """
    Parcourt récursivement un objet dict/list et renvoie la première valeur
    non vide trouvée pour une des clés demandées.
    """
    if isinstance(obj, dict):
        for key in keys:
            if key in obj and obj[key] not in (None, "", [], {}):
                return obj[key]
        for value in obj.values():
            found = find_first_value(value, keys)
            if found is not None:
                return found

    elif isinstance(obj, list):
        for item in obj:
            found = find_first_value(item, keys)
            if found is not None:
                return found

    return None

# %%
# Étape 1 : parsing du listing

def parse_listing_row(tr) -> Optional[Dict[str, Any]]:
    """
    Parse une ligne <tr> du listing.
    On récupère :
    - ticker_bourso depuis data-ist
    - les données de marché depuis data-ist-init
    - le lien détail pour l'étape 2
    """
    ticker_bourso = tr.get("data-ist")
    data_ist_init_raw = tr.get("data-ist-init", "")

    # Lien détail : il vaut mieux le suivre directement que le reconstruire
    link = tr.select_one("a[href*='/cours/']")
    detail_href = link.get("href") if link and link.has_attr("href") else None
    detail_url = urljoin(BASE_URL, detail_href) if detail_href else None

    # Le nom visible est souvent dans le lien
    name = link.get_text(" ", strip=True) if link else None
    if not name:
        # Fallback si la structure change légèrement
        text = tr.get_text(" ", strip=True)
        name = text or None

    # Parsing du JSON inline des marchés
    payload = extract_json_like(data_ist_init_raw)

    # Les clés exactes peuvent varier selon le site / l'objet embarqué.
    # On cherche donc les noms les plus probables.
    last = find_first_value(payload, ["last", "lastPrice", "price", "value"])
    variation = find_first_value(payload, ["variation", "change", "pctChange", "variationPercent"])
    high = find_first_value(payload, ["high", "dayHigh", "highPrice"])
    low = find_first_value(payload, ["low", "dayLow", "lowPrice"])
    volume = find_first_value(payload, ["volume", "tradedVolume", "turnover"])

    # Si la ligne est vide ou inutilisable, on l'ignore
    if not any([ticker_bourso, name, detail_url]):
        return None

    return {
        "name": name,
        "ticker_bourso": ticker_bourso,
        "detail_url": detail_url,
        "last": last,
        "variation": variation,
        "high": high,
        "low": low,
        "volume": volume,
        # Garde utile pour debug si vous voulez inspecter la structure brute
        "raw_data_ist_init": data_ist_init_raw,
    }


def scrape_listing_for_letter(letter: str) -> List[Dict[str, Any]]:
    """
    Récupère toutes les sociétés affichées pour une lettre donnée.
    Pas de pagination ici : on prend toutes les lignes du tableau statique.
    """
    params = {
        "quotation_az_filter[market]": MARKET,
        "quotation_az_filter[letter]": letter,
    }

    html_text = fetch_html(BASE_URL, params=params)
    soup = BeautifulSoup(html_text, "html.parser")

    rows = []
    for tr in soup.select("tr[data-ist-init]"):
        item = parse_listing_row(tr)
        if item:
            rows.append(item)

    return rows

# %%
# Étape 2 : enrichissement ISIN depuis la page détail

ISIN_RE = re.compile(r"\b[A-Z]{2}[A-Z0-9]{10}\b")


def extract_isin(detail_html: str) -> Optional[str]:
    """
    Extrait l'ISIN depuis la fiche détail.
    Cible principale : h2.c-faceplate__isin
    Fallback : regex sur le texte complet de la page
    """
    soup = BeautifulSoup(detail_html, "html.parser")

    # Cible principale
    h2 = soup.select_one("h2.c-faceplate__isin")
    if h2:
        text = h2.get_text(" ", strip=True)
        match = ISIN_RE.search(text)
        if match:
            return match.group(0)

    # Fallback si le sélecteur change légèrement
    page_text = soup.get_text(" ", strip=True)
    match = ISIN_RE.search(page_text)
    if match:
        return match.group(0)

    return None


def enrich_with_isin(row: Dict[str, Any]) -> Dict[str, Any]:
    """
    Télécharge la page détail et ajoute l'ISIN à la ligne courante.
    """
    detail_url = row.get("detail_url")
    if not detail_url:
        row["isin"] = ""
        return row

    detail_html = fetch_html(detail_url)
    row["isin"] = extract_isin(detail_html) or ""
    return row

# %%
# Programme principal

def main():
    """
    Pipeline complet :
    1) scrape listing sur 27 lettres
    2) dédoublonnage léger
    3) enrichissement ISIN
    4) export CSV final
    """
    all_rows: List[Dict[str, Any]] = []
    seen = set()

    # Étape 1 : listing
    for letter in LETTERS:
        print(f"[LISTING] Lettre {letter}...")
        rows = scrape_listing_for_letter(letter)

        for row in rows:
            # Clé de dédoublonnage :
            # on privilégie ticker_bourso, sinon le couple (nom, URL détail)
            key = row.get("ticker_bourso") or (row.get("name"), row.get("detail_url"))
            if key in seen:
                continue
            seen.add(key)
            all_rows.append(row)

        time.sleep(DELAY_SECONDS)

    print(f"[LISTING] Total lignes uniques : {len(all_rows)}")

    # Étape 2 : enrichissement ISIN
    for idx, row in enumerate(all_rows, start=1):
        name = row.get("name", "")
        print(f"[ISIN] {idx}/{len(all_rows)} - {name}")

        try:
            enrich_with_isin(row)
        except Exception as exc:
            # On ne bloque pas tout le run si une fiche pose problème
            row["isin"] = ""
            row["isin_error"] = str(exc)

        time.sleep(DELAY_SECONDS)

    # Export final
    fieldnames = [
        "name",
        "ticker_bourso",
        "isin",
        "detail_url",
        "last",
        "variation",
        "high",
        "low",
        "volume",
        "raw_data_ist_init",
    ]

    # On ajoute la colonne d'erreur seulement si elle existe quelque part
    if any("isin_error" in r for r in all_rows):
        fieldnames.append("isin_error")

    with open(OUTPUT_CSV, "w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=fieldnames, extrasaction="ignore")
        writer.writeheader()
        writer.writerows(all_rows)

    print(f"[OK] CSV final écrit dans : {OUTPUT_CSV}")


if __name__ == "__main__":
    main()
# Out:
# [LISTING] Lettre A...
# [LISTING] Lettre B...
# [LISTING] Lettre C...
# [LISTING] Lettre D...
# [LISTING] Lettre E...
# [LISTING] Lettre F...
# [LISTING] Lettre G...
# [LISTING] Lettre H...
# [LISTING] Lettre I...
# [LISTING] Lettre J...
# [LISTING] Lettre K...
# [LISTING] Lettre L...
# [LISTING] Lettre M...
# [LISTING] Lettre N...
# [LISTING] Lettre O...
# [LISTING] Lettre P...
# [LISTING] Lettre Q...
# [LISTING] Lettre R...
# [LISTING] Lettre S...
# [LISTING] Lettre T...
# [LISTING] Lettre U...
# [LISTING] Lettre V...
# [LISTING] Lettre W...
# [LISTING] Lettre X...
# [LISTING] Lettre Y...
# [LISTING] Lettre Z...
# [LISTING] Lettre 0...
# [LISTING] Total lignes uniques : 571
# [ISIN] 1/571 - AB SCIENCE
# [ISIN] 2/571 - ABC ARBITRAGE
# [ISIN] 3/571 - ABEO
# [ISIN] 4/571 - ABIONYX PHARMA
# [ISIN] 5/571 - ABIVAX
# [ISIN] 6/571 - ABL DIAGNOSTICS
# [ISIN] 7/571 - ACHETER-LOUER.FR
# [ISIN] 8/571 - ACTEOS (EX DATATRONIC)
# [ISIN] 9/571 - ACTIA GROUP
# [ISIN] 10/571 - ACTICOR BIOTECH
# [ISIN] 11/571 - ACTIVIUM GROUP
# [ISIN] 12/571 - ADEUNIS
# [ISIN] 13/571 - ADOCIA
# [ISIN] 14/571 - ADOMOS
# [ISIN] 15/571 - ADUX
# [ISIN] 16/571 - ADVICENNE
# [ISIN] 17/571 - ADVINI
# [ISIN] 18/571 - AELIS FARMA
# [ISIN] 19/571 - AFYREN
# [ISIN] 20/571 - AGRIPOWER
# [ISIN] 21/571 - AGROGENERATION
# [ISIN] 22/571 - AIR MARINE
# [ISIN] 23/571 - ACOMO
# [ISIN] 24/571 - ADUX
# [ISIN] 25/571 - AFC AJAX
# [ISIN] 26/571 - ALFEN
# [ISIN] 27/571 - ALMUNDA PROF
# [ISIN] 28/571 - ALUMEXX
# [ISIN] 29/571 - AMG CRIT MAT
# [ISIN] 30/571 - APERAM
# [ISIN] 31/571 - AVANTIUM
# [ISIN] 32/571 - AZERION CO
# [ISIN] 33/571 - ABO-GROUP
# [ISIN] 34/571 - ACCENTIS
# [ISIN] 35/571 - ADEC INNOVATIONS
# [ISIN] 36/571 - ADVICENNE
# [ISIN] 37/571 - AGFA-GEVAERT
# [ISIN] 38/571 - ATENOR
# [ISIN] 39/571 - AVANTIUM
# [ISIN] 40/571 - BAIKOWSKI
# [ISIN] 41/571 - BALYO
# [ISIN] 42/571 - BARBARA BUI
# [ISIN] 43/571 - BASSAC
# [ISIN] 44/571 - BASTIDE LE CONFORT MED.
# [ISIN] 45/571 - BELIEVE
# [ISIN] 46/571 - BENETEAU
# [ISIN] 47/571 - BERNARD LOISEAU
# [ISIN] 48/571 - BIGBEN INTERACTIVE
# [ISIN] 49/571 - BILENDI
# [ISIN] 50/571 - BIO-INOX
# [ISIN] 51/571 - BIO-UV GRP
# [ISIN] 52/571 - BIOCORP
# [ISIN] 53/571 - BIOPHYTIS
# [ISIN] 54/571 - BIOSYNEX
# [ISIN] 55/571 - BLUE SHARK PS
# [ISIN] 56/571 - BLUELINEA
# [ISIN] 57/571 - BOA CONCEPT
# [ISIN] 58/571 - BODY ONE
# [ISIN] 59/571 - BOIRON
# [ISIN] 60/571 - BONDUELLE
# [ISIN] 61/571 - BONYF
# [ISIN] 62/571 - BOOSTHEAT
# [ISIN] 63/571 - BOURRELIER GRP
# [ISIN] 64/571 - B&S GROUP
# [ISIN] 65/571 - BASIC-FIT
# [ISIN] 66/571 - BENEVOLENTAI
# [ISIN] 67/571 - BRUNEL INTL
# [ISIN] 68/571 - BANIMMO
# [ISIN] 69/571 - BANQUP GRP
# [ISIN] 70/571 - BARCO
# [ISIN] 71/571 - BEKAERT
# [ISIN] 72/571 - BELYSSE GRP
# [ISIN] 73/571 - BIOCARTIS GR-UNTY
# [ISIN] 74/571 - BIOSENIC
# [ISIN] 75/571 - BIOTALYS
# [ISIN] 76/571 - BNB
# [ISIN] 77/571 - BPOST
# [ISIN] 78/571 - CA TOULOUSE 31 CCI
# [ISIN] 79/571 - CABASSE
# [ISIN] 80/571 - CAFOM
# [ISIN] 81/571 - CALIBRE
# [ISIN] 82/571 - CAPELLI
# [ISIN] 83/571 - CAPITAL B
# [ISIN] 84/571 - CARBIOS
# [ISIN] 85/571 - CARMAT
# [ISIN] 86/571 - CARPINIENNE PART.
# [ISIN] 87/571 - CARVOLIX
# [ISIN] 88/571 - CASINO CANNES
# [ISIN] 89/571 - CASINO GUICHARD
# [ISIN] 90/571 - CAST
# [ISIN] 91/571 - CATANA GROUP
# [ISIN] 92/571 - CBO TERRITORIA
# [ISIN] 93/571 - CEGEDIM
# [ISIN] 94/571 - CELLECTIS
# [ISIN] 95/571 - CELLNOVO GROUP
# [ISIN] 96/571 - CABKA
# [ISIN] 97/571 - CM.COM
# [ISIN] 98/571 - CORBION
# [ISIN] 99/571 - CTAC
# [ISIN] 100/571 - CAMPINE
# [ISIN] 101/571 - CANDELA INVEST
# [ISIN] 102/571 - CELYAD ONCO
# [ISIN] 103/571 - CENERGY HLDG
# [ISIN] 104/571 - CFE
# [ISIN] 105/571 - CHOICE
# [ISIN] 106/571 - CIE DU BOIS SAUVAGE
# [ISIN] 107/571 - CO.BR.HA.
# [ISIN] 108/571 - CUMULEX
# [ISIN] 109/571 - DAMARIS
# [ISIN] 110/571 - DAMARTEX
# [ISIN] 111/571 - DATBIM
# [ISIN] 112/571 - DBT
# [ISIN] 113/571 - DBV TECHNOLOGIES
# [ISIN] 114/571 - DEEZER
# [ISIN] 115/571 - DEINOVE
# [ISIN] 116/571 - DEKUPLE
# [ISIN] 117/571 - DELFINGEN
# [ISIN] 118/571 - DELTA PLUS GRP
# [ISIN] 119/571 - DERICHEBOURG
# [ISIN] 120/571 - DEVERNOIS
# [ISIN] 121/571 - DLSI
# [ISIN] 122/571 - DMS
# [ISIN] 123/571 - DNXCORP
# [ISIN] 124/571 - DOCKS PETR.D'AMBE
# [ISIN] 125/571 - DOLFINES
# [ISIN] 126/571 - DONTNOD
# [ISIN] 127/571 - DRONE VOLT
# [ISIN] 128/571 - DYNAFOND
# [ISIN] 129/571 - DYNEX ENERGY
# [ISIN] 130/571 - DECEUNINCK
# [ISIN] 131/571 - E-PANGO
# [ISIN] 132/571 - E.A.V.S. GROUPE
# [ISIN] 133/571 - EAGLE FOOTBALL GR
# [ISIN] 134/571 - EAUX DE ROYAN
# [ISIN] 135/571 - ECOLUTIONS
# [ISIN] 136/571 - ECOMIAM
# [ISIN] 137/571 - ECOSLOPS
# [ISIN] 138/571 - EDILIZIACROB
# [ISIN] 139/571 - EDITIONS DU SIGNE
# [ISIN] 140/571 - EDUFORM'ACTION
# [ISIN] 141/571 - EDUNIVERSAL
# [ISIN] 142/571 - EEM
# [ISIN] 143/571 - EGEIRO PHARMA
# [ISIN] 144/571 - EGIDE
# [ISIN] 145/571 - EKINOPS
# [ISIN] 146/571 - ELECTRICITE DE STRASBOURG
# [ISIN] 147/571 - ELIOR GROUP
# [ISIN] 148/571 - EMB SIST INTEL
# [ISIN] 149/571 - EMEIS
# [ISIN] 150/571 - EMOVA GRP
# [ISIN] 151/571 - ENCRES DUBUIT
# [ISIN] 152/571 - ENENSYS TECHNO
# [ISIN] 153/571 - EASE2PAY
# [ISIN] 154/571 - EBUSCO BR RG-UNTY
# [ISIN] 155/571 - EBUSCO HLDG
# [ISIN] 156/571 - EHC RG-A
# [ISIN] 157/571 - ENVIPCO HLDG
# [ISIN] 158/571 - ER CAPITAL
# [ISIN] 159/571 - ECONOCOM GROUP
# [ISIN] 160/571 - EKOPAK
# [ISIN] 161/571 - ENERGYVISION
# [ISIN] 162/571 - EU MED SOL
# [ISIN] 163/571 - EVS BROADCAST EQU
# [ISIN] 164/571 - EXMAR
# [ISIN] 165/571 - FACEPHI BIOMETR
# [ISIN] 166/571 - FASHION B AIR
# [ISIN] 167/571 - FCE SOIR GRP
# [ISIN] 168/571 - FD
# [ISIN] 169/571 - FERMENTALG
# [ISIN] 170/571 - FIDUCIAL OFF.SOLU
# [ISIN] 171/571 - FIDUCIAL REAL ESTATE
# [ISIN] 172/571 - FIEBM
# [ISIN] 173/571 - FIGEAC AERO
# [ISIN] 174/571 - FILAE
# [ISIN] 175/571 - FILL UP MEDIA
# [ISIN] 176/571 - FIN MARJOS
# [ISIN] 177/571 - FINANCIERE MONCEY
# [ISIN] 178/571 - FINATIS
# [ISIN] 179/571 - FINAXO
# [ISIN] 180/571 - FLEURY MICHON
# [ISIN] 181/571 - FLORENTAISE
# [ISIN] 182/571 - FNAC DARTY
# [ISIN] 183/571 - FNP TECH
# [ISIN] 184/571 - FONCIERE 7 INV
# [ISIN] 185/571 - FONCIERE EURIS
# [ISIN] 186/571 - FONCIERE VINDI
# [ISIN] 187/571 - FONCIERE VOLTA
# [ISIN] 188/571 - FORFARMERS
# [ISIN] 189/571 - FUGRO
# [ISIN] 190/571 - FAGRON
# [ISIN] 191/571 - FIN NEUFCOUR
# [ISIN] 192/571 - FLORIDIENNE
# [ISIN] 193/571 - FLOWSPARKS
# [ISIN] 194/571 - FLUXYS BELGIUM
# [ISIN] 195/571 - FOUNTAIN
# [ISIN] 196/571 - GAI (EX.EFE EDITION FORMATION)
# [ISIN] 197/571 - GALEO
# [ISIN] 198/571 - GALIMMO
# [ISIN] 199/571 - GASCOGNE
# [ISIN] 200/571 - GAUMONT
# [ISIN] 201/571 - GAUSSIN
# [ISIN] 202/571 - GEA
# [ISIN] 203/571 - GECI INTL
# [ISIN] 204/571 - GENERIX GRP
# [ISIN] 205/571 - GENFIT
# [ISIN] 206/571 - GENOMIC VISION
# [ISIN] 207/571 - GENOWAY
# [ISIN] 208/571 - GENSIGHT BIOLOGICS
# [ISIN] 209/571 - GENTLEMEN'S
# [ISIN] 210/571 - GEVELOT
# [ISIN] 211/571 - GL EVENTS
# [ISIN] 212/571 - GLASS TO POW
# [ISIN] 213/571 - GLASS TO POW RG-A
# [ISIN] 214/571 - GLASS TO POW RG-B
# [ISIN] 215/571 - GLOBAL BIOENERGIES
# [ISIN] 216/571 - GOLD BY GOLD
# [ISIN] 217/571 - GPE PIZZORNO ENVI
# [ISIN] 218/571 - GPE PLUS-VALUES
# [ISIN] 219/571 - GROLLEAU
# [ISIN] 220/571 - GROUPE AG3I
# [ISIN] 221/571 - GALAPAGOS
# [ISIN] 222/571 - GREEN EARTH GRP
# [ISIN] 223/571 - GIMV
# [ISIN] 224/571 - H&K
# [ISIN] 225/571 - HAFFNER ENERGY
# [ISIN] 226/571 - HAULOTTE GROUP
# [ISIN] 227/571 - HEALTH
# [ISIN] 228/571 - HERIGE
# [ISIN] 229/571 - HEXAOM
# [ISIN] 230/571 - HF COMPANY
# [ISIN] 231/571 - HIGH CO
# [ISIN] 232/571 - HIPAY GROUP
# [ISIN] 233/571 - HITECHPROS
# [ISIN] 234/571 - HOCHE BAINS LES BAINS
# [ISIN] 235/571 - HOFFMANN GREEN CEMENT TEC.
# [ISIN] 236/571 - HOME CONCEPT
# [ISIN] 237/571 - HOPENING
# [ISIN] 238/571 - HOPIUM
# [ISIN] 239/571 - HOPSCOTCH GRP
# [ISIN] 240/571 - HOTEL MAJESTIC CANNES
# [ISIN] 241/571 - HOTEL REGINA PARIS
# [ISIN] 242/571 - HOTELES BESTPR
# [ISIN] 243/571 - HOTELIERE IMMOBILIERE DE NICE
# [ISIN] 244/571 - HOTELIM
# [ISIN] 245/571 - HOTELS DE PARIS
# [ISIN] 246/571 - HRS (HYDROGEN REFUELING SOL.)
# [ISIN] 247/571 - HUNYVERS
# [ISIN] 248/571 - HYDRAULIQUE HLD
# [ISIN] 249/571 - HAVAS
# [ISIN] 250/571 - HOLLAND COLOURS
# [ISIN] 251/571 - HYDRATEC NV
# [ISIN] 252/571 - HYLORIS PHARMACEUTICALS
# [ISIN] 253/571 - I.CERAM
# [ISIN] 254/571 - I2S
# [ISIN] 255/571 - ICAPE HOLDING
# [ISIN] 256/571 - ID LOGISTICS
# [ISIN] 257/571 - IDI
# [ISIN] 258/571 - IDS
# [ISIN] 259/571 - IDSUD
# [ISIN] 260/571 - IEVA GROUP
# [ISIN] 261/571 - IKONISYS
# [ISIN] 262/571 - IMALLIANCE
# [ISIN] 263/571 - IMEON ENERGY
# [ISIN] 264/571 - IMM.PARIS.PERLE
# [ISIN] 265/571 - IMMERSION
# [ISIN] 266/571 - IMPLANET
# [ISIN] 267/571 - IMPRIMERIE CHIRAT
# [ISIN] 268/571 - IMPULSE FITNESS
# [ISIN] 269/571 - INFOCLIP
# [ISIN] 270/571 - INFOTEL
# [ISIN] 271/571 - INMOLECULE NANO
# [ISIN] 272/571 - INNATE PHARMA
# [ISIN] 273/571 - INNELEC MULTIMEDIA
# [ISIN] 274/571 - INNOVATIVE-RFK
# [ISIN] 275/571 - INSTALLUX
# [ISIN] 276/571 - INTEGRAGEN
# [ISIN] 277/571 - INTEGRIT VIAGER
# [ISIN] 278/571 - IEX GROUP
# [ISIN] 279/571 - IBA
# [ISIN] 280/571 - IEP INVEST
# [ISIN] 281/571 - IMMOBEL
# [ISIN] 282/571 - INCLUSIO
# [ISIN] 283/571 - JACQUES BOGART
# [ISIN] 284/571 - JACQUET METALS
# [ISIN] 285/571 - JUNGLE21
# [ISIN] 286/571 - JENSEN-GROUP
# [ISIN] 287/571 - KALEON
# [ISIN] 288/571 - KALRAY
# [ISIN] 289/571 - KAUFMAN ET BROAD
# [ISIN] 290/571 - KERLINK
# [ISIN] 291/571 - KEYRUS
# [ISIN] 292/571 - KKO INTL
# [ISIN] 293/571 - KLARSEN
# [ISIN] 294/571 - KLEA HOLDING (ex VISIOMED)
# [ISIN] 295/571 - KUMULUS VAPE
# [ISIN] 296/571 - KENDRION
# [ISIN] 297/571 - KON BAM GROEP
# [ISIN] 298/571 - KON PORC FL
# [ISIN] 299/571 - KEYWARE TECH
# [ISIN] 300/571 - KINEPOLIS GROUP
# [ISIN] 301/571 - L'AGENCE AUTOMOBILIERE
# [ISIN] 302/571 - LA CHAUSSERIA
# [ISIN] 303/571 - LA PERLA FASHION HLDG
# [ISIN] 304/571 - LACROIX
# [ISIN] 305/571 - LANSON-BCC
# [ISIN] 306/571 - LARGO
# [ISIN] 307/571 - LATECOERE
# [ISIN] 308/571 - LATECOERE
# [ISIN] 309/571 - LAURENT PERRIER
# [ISIN] 310/571 - LDC
# [ISIN] 311/571 - LE TANNEUR
# [ISIN] 312/571 - LEBON
# [ISIN] 313/571 - LECTRA
# [ISIN] 314/571 - LECTRA
# [ISIN] 315/571 - LEPERMISLIBRE
# [ISIN] 316/571 - LES CONSTRUCTEURS DU BOIS
# [ISIN] 317/571 - LEXIBOOK LINGUIST
# [ISIN] 318/571 - LHYFE
# [ISIN] 319/571 - LIGHTON
# [ISIN] 320/571 - LINEDATA SERVICES
# [ISIN] 321/571 - LISI
# [ISIN] 322/571 - LLEID SERV TELEM
# [ISIN] 323/571 - LAVIDE HOLDING
# [ISIN] 324/571 - M2I
# [ISIN] 325/571 - M6 METROPOLE TELE.
# [ISIN] 326/571 - MAAT PHARMA
# [ISIN] 327/571 - MACOMPTA.FR
# [ISIN] 328/571 - MACOMPTA.FR
# [ISIN] 329/571 - MADE
# [ISIN] 330/571 - MAIS POMM & ASS
# [ISIN] 331/571 - MAISON ANTOINE BAUD
# [ISIN] 332/571 - MAISON CLIO
# [ISIN] 333/571 - MAISONS DU MONDE
# [ISIN] 334/571 - MAKING SCI GRP
# [ISIN] 335/571 - MALTER.FRANCO-BEL
# [ISIN] 336/571 - MANITOU BF
# [ISIN] 337/571 - MANUTAN INTL
# [ISIN] 338/571 - MARE NOSTRUM
# [ISIN] 339/571 - MARIE BRIZARD
# [ISIN] 340/571 - MASTRAD
# [ISIN] 341/571 - MAUNA KEA
# [ISIN] 342/571 - MAUREL & PROM
# [ISIN] 343/571 - MKB NEDSENSE
# [ISIN] 344/571 - MAIS POMM & ASS
# [ISIN] 345/571 - MATERIALISE
# [ISIN] 346/571 - MAZARO
# [ISIN] 347/571 - MIKO
# [ISIN] 348/571 - MOURY CONSTRUCT
# [ISIN] 349/571 - NACON
# [ISIN] 350/571 - NAM.R
# [ISIN] 351/571 - NANOBIOTIX
# [ISIN] 352/571 - NAVYA
# [ISIN] 353/571 - NEOLIFE
# [ISIN] 354/571 - NEOVACS
# [ISIN] 355/571 - NETGEM
# [ISIN] 356/571 - NETMEDIA GROUP
# [ISIN] 357/571 - NEURONES
# [ISIN] 358/571 - NEXITY
# [ISIN] 359/571 - NEXTEDIA
# [ISIN] 360/571 - NFL BIOSCIENCES
# [ISIN] 361/571 - NFTY
# [ISIN] 362/571 - NHOA
# [ISIN] 363/571 - NICOLAS MIGUET N
# [ISIN] 364/571 - NICOX
# [ISIN] 365/571 - NORTEM BIOGROUP
# [ISIN] 366/571 - NORTH ATLANTIC ENERGIES
# [ISIN] 367/571 - NOVACYT
# [ISIN] 368/571 - NOVATECH INDUSTRIES
# [ISIN] 369/571 - NR21
# [ISIN] 370/571 - NRJ GRP
# [ISIN] 371/571 - NSC GROUPE
# [ISIN] 372/571 - NEDAP
# [ISIN] 373/571 - NEW AMS INV
# [ISIN] 374/571 - NEW SOURCES ENER
# [ISIN] 375/571 - NV BEVER HOLDING
# [ISIN] 376/571 - NX FILTRATION
# [ISIN] 377/571 - NEWTREE
# [ISIN] 378/571 - NYRSTAR
# [ISIN] 379/571 - NYXOAH
# [ISIN] 380/571 - O SORBET D'AMOUR
# [ISIN] 381/571 - OBER
# [ISIN] 382/571 - OBIZ
# [ISIN] 383/571 - OCTOPUS BIOSAF
# [ISIN] 384/571 - ODIOT
# [ISIN] 385/571 - ODYSSEE TECHNOLOGIES
# [ISIN] 386/571 - OENEO
# [ISIN] 387/571 - OMER-DECUGIS & CIE
# [ISIN] 388/571 - ONCODESIGN PM
# [ISIN] 389/571 - ONE EXPERIENCE
# [ISIN] 390/571 - ONLINEFORMAPRO N
# [ISIN] 391/571 - OPMOBILITY (EX PLASTIC OM.)
# [ISIN] 392/571 - ORAPI
# [ISIN] 393/571 - ORCHESTRA-PREMAMAN
# [ISIN] 394/571 - ORDISSIMO
# [ISIN] 395/571 - OREGE
# [ISIN] 396/571 - OSE IMMUNO
# [ISIN] 397/571 - OSMOZIS
# [ISIN] 398/571 - OVHCLOUD
# [ISIN] 399/571 - OCI
# [ISIN] 400/571 - ONTEX GROUP
# [ISIN] 401/571 - ONWARD MEDICAL
# [ISIN] 402/571 - OPTION
# [ISIN] 403/571 - ORANGE BE
# [ISIN] 404/571 - OXURION
# [ISIN] 405/571 - PACTE NOVATION
# [ISIN] 406/571 - PARAGON ID
# [ISIN] 407/571 - PARROT
# [ISIN] 408/571 - PART.INDLES MINI.
# [ISIN] 409/571 - PARTOUCHE
# [ISIN] 410/571 - PARX MATERIALS
# [ISIN] 411/571 - PASSAT
# [ISIN] 412/571 - PAULIC MEUNERIE
# [ISIN] 413/571 - PCAS
# [ISIN] 414/571 - PERRIER INDUSTRIE
# [ISIN] 415/571 - PET SVC HLDG
# [ISIN] 416/571 - PEUGEOT INVEST
# [ISIN] 417/571 - PHARMASIMPLE
# [ISIN] 418/571 - PHARNEXT
# [ISIN] 419/571 - PHAXIAM THERAPEUTICS
# [ISIN] 420/571 - PHERECYDES PHARMA
# [ISIN] 421/571 - PHONE WEB
# [ISIN] 422/571 - PHOTONIKE
# [ISIN] 423/571 - PIERRE ET VACANCES
# [ISIN] 424/571 - PISCINES DESJOYAUX
# [ISIN] 425/571 - PIXIUM VISION
# [ISIN] 426/571 - PB HOLDING NV
# [ISIN] 427/571 - PHARMING GROUP
# [ISIN] 428/571 - POSTNL
# [ISIN] 429/571 - PALMERAIES MOPOLI
# [ISIN] 430/571 - PROXIMUS
# [ISIN] 431/571 - QUADIENT
# [ISIN] 432/571 - QUADPACK INDUSTR
# [ISIN] 433/571 - QUANTUM GENOMICS
# [ISIN] 434/571 - QWAMPLIFY
# [ISIN] 435/571 - RACING FORCE
# [ISIN] 436/571 - RAMSAY GENERALE
# [ISIN] 437/571 - RAPIDO PRET
# [ISIN] 438/571 - REALITES
# [ISIN] 439/571 - REBIRTH
# [ISIN] 440/571 - REBOOST BLOCKCHAIN CORP
# [ISIN] 441/571 - REMY COINTREAU
# [ISIN] 442/571 - REWORLD MEDIA
# [ISIN] 443/571 - RIBER
# [ISIN] 444/571 - RISING STONE
# [ISIN] 445/571 - ROBERTET
# [ISIN] 446/571 - ROBERTET CI E87
# [ISIN] 447/571 - ROCHE BOBOIS
# [ISIN] 448/571 - ROCTOOL
# [ISIN] 449/571 - ROUGIER S.A.
# [ISIN] 450/571 - REALCO
# [ISIN] 451/571 - RECTICEL
# [ISIN] 452/571 - REIBEL
# [ISIN] 453/571 - RMG
# [ISIN] 454/571 - SAFE
# [ISIN] 455/571 - SAINT JEAN GRP
# [ISIN] 456/571 - SAMSE
# [ISIN] 457/571 - SAPMER
# [ISIN] 458/571 - SAVENCIA
# [ISIN] 459/571 - SAVONNERIE  NYONS
# [ISIN] 460/571 - SCEMI
# [ISIN] 461/571 - SCIENTIA SCHOOL
# [ISIN] 462/571 - SCIENTIFIC BRAIN
# [ISIN] 463/571 - SECHE ENVIRONNEMENT
# [ISIN] 464/571 - SELCODIS (EX. SUPERVOX GROUPE)
# [ISIN] 465/571 - SEMCO TECHNOLOGIES
# [ISIN] 466/571 - SENSORION
# [ISIN] 467/571 - SEQUA PETROLEUM
# [ISIN] 468/571 - SERGE FERRARI
# [ISIN] 469/571 - SHOWROOMPRIVE
# [ISIN] 470/571 - SIDETRADE
# [ISIN] 471/571 - SIGNAUX GIROD
# [ISIN] 472/571 - SIP MOV
# [ISIN] 473/571 - SIRIUS MEDIA
# [ISIN] 474/571 - SMAIO
# [ISIN] 475/571 - SIF HLD
# [ISIN] 476/571 - SLIGRO FOOD GROU
# [ISIN] 477/571 - SEQUANA MEDICAL
# [ISIN] 478/571 - SIPEF
# [ISIN] 479/571 - SMARTPHOTO GR
# [ISIN] 480/571 - SOFTIMAT
# [ISIN] 481/571 - SOLVAC
# [ISIN] 482/571 - SONAECOM
# [ISIN] 483/571 - SPADEL
# [ISIN] 484/571 - TARKETT
# [ISIN] 485/571 - TBSO
# [ISIN] 486/571 - TECHNOFIRST
# [ISIN] 487/571 - TELEVISTA
# [ISIN] 488/571 - TERACT
# [ISIN] 489/571 - TF1
# [ISIN] 490/571 - TF1
# [ISIN] 491/571 - TF1
# [ISIN] 492/571 - TFF GROUP
# [ISIN] 493/571 - THE AZUR SEL
# [ISIN] 494/571 - THERACLION
# [ISIN] 495/571 - THERADIAG
# [ISIN] 496/571 - THERMADOR
# [ISIN] 497/571 - THX PHARMA (EX THERANEXUS)
# [ISIN] 498/571 - TIPIAK
# [ISIN] 499/571 - TITAN
# [ISIN] 500/571 - TME PHARMA
# [ISIN] 501/571 - TONNER DRONES
# [ISIN] 502/571 - TOOLUX SANDING
# [ISIN] 503/571 - TOOSLA
# [ISIN] 504/571 - TOUAX
# [ISIN] 505/571 - THEON INTL
# [ISIN] 506/571 - TOMTOM
# [ISIN] 507/571 - TESSELLIS
# [ISIN] 508/571 - TESSENDERLO GR
# [ISIN] 509/571 - TEXAF
# [ISIN] 510/571 - TINC
# [ISIN] 511/571 - TITAN
# [ISIN] 512/571 - U10 CORP
# [ISIN] 513/571 - UBISOFT
# [ISIN] 514/571 - UMALIS GROUP
# [ISIN] 515/571 - UNITI
# [ISIN] 516/571 - UPERGY
# [ISIN] 517/571 - UTI GROUP
# [ISIN] 518/571 - UV GERMI
# [ISIN] 519/571 - UCARE SVC BE
# [ISIN] 520/571 - VALBIOTIS
# [ISIN] 521/571 - VALERIO THER. (EX ONXEO)
# [ISIN] 522/571 - VALNEVA
# [ISIN] 523/571 - VALONEO
# [ISIN] 524/571 - VANTIVA
# [ISIN] 525/571 - VAZIVA
# [ISIN] 526/571 - VELCAN HLDG
# [ISIN] 527/571 - VENTE UNIQUE.COM
# [ISIN] 528/571 - VEOM GROUP
# [ISIN] 529/571 - VERGNET
# [ISIN] 530/571 - VERIMATRIX
# [ISIN] 531/571 - VERNEY-CARRON
# [ISIN] 532/571 - VERSITY
# [ISIN] 533/571 - VETOQUINOL
# [ISIN] 534/571 - VIALIFE
# [ISIN] 535/571 - VICAT
# [ISIN] 536/571 - VIEL
# [ISIN] 537/571 - VINPAI
# [ISIN] 538/571 - VIRBAC
# [ISIN] 539/571 - VIRIDIEN
# [ISIN] 540/571 - VIRTUALWARE
# [ISIN] 541/571 - VISIATIV
# [ISIN] 542/571 - VOGO
# [ISIN] 543/571 - VALUE8
# [ISIN] 544/571 - VIVORYON THER
# [ISIN] 545/571 - VAN DE VELDE
# [ISIN] 546/571 - VGP
# [ISIN] 547/571 - VIOHALCO
# [ISIN] 548/571 - WAGA ENERGY
# [ISIN] 549/571 - WALLIX GROUP
# [ISIN] 550/571 - WATERA
# [ISIN] 551/571 - WAVESTONE
# [ISIN] 552/571 - WE.CONNECT
# [ISIN] 553/571 - WEACCESS GRP
# [ISIN] 554/571 - WEDIA
# [ISIN] 555/571 - WEYA
# [ISIN] 556/571 - WIDECH
# [ISIN] 557/571 - WINAMP GROUP
# [ISIN] 558/571 - WINFARM
# [ISIN] 559/571 - WITBE
# [ISIN] 560/571 - WIZIBOAT
# [ISIN] 561/571 - WORLDLINE
# [ISIN] 562/571 - WHATS
# [ISIN] 563/571 - WHITESTONE GRP
# [ISIN] 564/571 - WINAMP GROUP
# [ISIN] 565/571 - X-FAB SILICON
# [ISIN] 566/571 - XILAM ANIMATION
# [ISIN] 567/571 - YOUNITED FINL
# [ISIN] 568/571 - YOUNITED FINANCIAL
# [ISIN] 569/571 - 1000MERCIS
# [ISIN] 570/571 - 2CRSI
# [ISIN] 571/571 - 74SOFTWARE
# [OK] CSV final écrit dans : boursorama_peapme_final.csv
